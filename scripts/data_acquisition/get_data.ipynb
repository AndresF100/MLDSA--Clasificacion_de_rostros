# %%
#get zip
# !cd ./data
# !kaggle datasets download -d stoicstatic/face-recognition-dataset
# Out:
# Downloading face-recognition-dataset.zip to d:\OneDrive - Universidad de La Salle\Documents\GitHub\tdsp_template\scripts\data_acquisition
#   0%|          | 0.00/181M [00:00<?, ?B/s]
#   1%|          | 1.00M/181M [00:00<01:08, 2.75MB/s]
#   1%|          | 2.00M/181M [00:00<00:49, 3.79MB/s]
#   2%|▏         | 3.00M/181M [00:00<00:41, 4.49MB/s]
#   2%|▏         | 4.00M/181M [00:00<00:39, 4.70MB/s]
#   3%|▎         | 5.00M/181M [00:01<00:36, 5.02MB/s]
#   3%|▎         | 6.00M/181M [00:01<00:34, 5.40MB/s]
#   4%|▍         | 7.00M/181M [00:01<00:32, 5.62MB/s]
#   4%|▍         | 8.00M/181M [00:01<00:31, 5.76MB/s]
#   5%|▍         | 9.00M/181M [00:01<00:30, 5.94MB/s]
#   6%|▌         | 10.0M/181M [00:01<00:29, 6.03MB/s]
#   6%|▌         | 11.0M/181M [00:02<00:29, 6.06MB/s]
#   7%|▋         | 12.0M/181M [00:02<00:29, 6.04MB/s]
#   7%|▋         | 13.0M/181M [00:02<00:29, 5.91MB/s]
#   8%|▊         | 14.0M/181M [00:02<00:28, 6.18MB/s]
#   8%|▊         | 15.0M/181M [00:02<00:27, 6.24MB/s]
#   9%|▉         | 16.0M/181M [00:02<00:26, 6.45MB/s]
#   9%|▉         | 17.0M/181M [00:03<00:28, 6.00MB/s]
#  10%|▉         | 18.0M/181M [00:03<00:27, 6.13MB/s]
#  10%|█         | 19.0M/181M [00:03<00:26, 6.34MB/s]
#  11%|█         | 20.0M/181M [00:03<00:26, 6.40MB/s]
#  12%|█▏        | 21.0M/181M [00:03<00:26, 6.38MB/s]
#  12%|█▏        | 22.0M/181M [00:04<00:26, 6.33MB/s]
#  13%|█▎        | 23.0M/181M [00:04<00:27, 5.97MB/s]
#  13%|█▎        | 24.0M/181M [00:04<00:29, 5.53MB/s]
#  14%|█▍        | 25.0M/181M [00:04<00:44, 3.69MB/s]
#  14%|█▍        | 26.0M/181M [00:05<00:38, 4.20MB/s]
#  15%|█▍        | 27.0M/181M [00:05<00:34, 4.69MB/s]
#  15%|█▌        | 28.0M/181M [00:05<00:31, 5.14MB/s]
#  16%|█▌        | 29.0M/181M [00:05<00:28, 5.54MB/s]
#  17%|█▋        | 30.0M/181M [00:05<00:33, 4.74MB/s]
#  17%|█▋        | 31.0M/181M [00:06<00:39, 4.02MB/s]
#  18%|█▊        | 32.0M/181M [00:06<00:41, 3.80MB/s]
#  18%|█▊        | 33.0M/181M [00:06<00:35, 4.32MB/s]
#  19%|█▉        | 34.0M/181M [00:06<00:32, 4.69MB/s]
#  19%|█▉        | 35.0M/181M [00:07<00:30, 5.10MB/s]
#  20%|█▉        | 36.0M/181M [00:07<00:28, 5.34MB/s]
#  20%|██        | 37.0M/181M [00:07<00:27, 5.58MB/s]
#  21%|██        | 38.0M/181M [00:07<00:26, 5.72MB/s]
#  22%|██▏       | 39.0M/181M [00:07<00:25, 5.88MB/s]
#  22%|██▏       | 40.0M/181M [00:07<00:24, 6.11MB/s]
#  70%|███████   | 127M/181M [00:22<00:08, 6.80MB/s]
#  71%|███████   | 128M/181M [00:23<00:08, 6.55MB/s]
#  71%|███████   | 129M/181M [00:23<00:08, 6.60MB/s]
#  72%|███████▏  | 130M/181M [00:23<00:11, 4.84MB/s]
#  72%|███████▏  | 131M/181M [00:23<00:10, 5.23MB/s]
#  73%|███████▎  | 132M/181M [00:23<00:09, 5.67MB/s]
#  73%|███████▎  | 133M/181M [00:23<00:08, 5.97MB/s]
#  74%|███████▍  | 134M/181M [00:24<00:07, 6.20MB/s]
#  75%|███████▍  | 135M/181M [00:24<00:07, 6.28MB/s]
#  75%|███████▌  | 136M/181M [00:24<00:07, 6.49MB/s]
#  76%|███████▌  | 137M/181M [00:24<00:07, 6.57MB/s]
#  76%|███████▌  | 138M/181M [00:24<00:06, 6.75MB/s]
#  77%|███████▋  | 139M/181M [00:24<00:06, 6.77MB/s]
#  77%|███████▋  | 140M/181M [00:25<00:06, 6.73MB/s]
#  78%|███████▊  | 141M/181M [00:25<00:06, 6.76MB/s]
#  78%|███████▊  | 142M/181M [00:25<00:06, 6.75MB/s]
#  79%|███████▉  | 143M/181M [00:25<00:06, 6.63MB/s]
#  80%|███████▉  | 144M/181M [00:25<00:05, 6.71MB/s]
#  80%|████████  | 145M/181M [00:25<00:05, 6.69MB/s]
#  81%|████████  | 146M/181M [00:26<00:05, 6.76MB/s]
#  81%|████████  | 147M/181M [00:26<00:05, 6.62MB/s]
#  82%|████████▏ | 148M/181M [00:26<00:05, 6.70MB/s]
#  82%|████████▏ | 149M/181M [00:26<00:05, 6.48MB/s]
#  83%|████████▎ | 150M/181M [00:26<00:04, 6.59MB/s]
#  83%|████████▎ | 151M/181M [00:26<00:04, 6.48MB/s]
#  84%|████████▍ | 152M/181M [00:26<00:04, 6.48MB/s]
#  84%|████████▍ | 153M/181M [00:27<00:04, 6.39MB/s]
#  85%|████████▌ | 154M/181M [00:27<00:04, 6.46MB/s]
#  86%|████████▌ | 155M/181M [00:27<00:04, 6.53MB/s]
#  86%|████████▌ | 156M/181M [00:27<00:03, 6.63MB/s]
#  87%|████████▋ | 157M/181M [00:27<00:03, 6.70MB/s]
#  87%|████████▋ | 158M/181M [00:27<00:03, 6.65MB/s]
#  88%|████████▊ | 159M/181M [00:28<00:03, 6.65MB/s]
#  88%|████████▊ | 160M/181M [00:28<00:03, 6.42MB/s]
#  89%|████████▉ | 161M/181M [00:28<00:03, 6.37MB/s]
#  89%|████████▉ | 162M/181M [00:28<00:03, 6.44MB/s]
#  90%|█████████ | 163M/181M [00:28<00:02, 6.56MB/s]
#  91%|█████████ | 164M/181M [00:28<00:02, 6.54MB/s]
#  91%|█████████ | 165M/181M [00:29<00:02, 6.74MB/s]
#  92%|█████████▏| 166M/181M [00:29<00:02, 6.35MB/s]
#  92%|█████████▏| 167M/181M [00:29<00:02, 6.25MB/s]
#  93%|█████████▎| 168M/181M [00:29<00:02, 4.69MB/s]
#  93%|█████████▎| 169M/181M [00:30<00:02, 4.30MB/s]
#  94%|█████████▍| 170M/181M [00:30<00:02, 4.97MB/s]
#  94%|█████████▍| 171M/181M [00:30<00:02, 5.23MB/s]
#  95%|█████████▍| 172M/181M [00:30<00:02, 4.29MB/s]
#  96%|█████████▌| 173M/181M [00:30<00:01, 4.84MB/s]
#  96%|█████████▌| 174M/181M [00:31<00:01, 5.28MB/s]
#  97%|█████████▋| 175M/181M [00:31<00:01, 5.74MB/s]
#  97%|█████████▋| 176M/181M [00:31<00:00, 6.02MB/s]
#  98%|█████████▊| 177M/181M [00:31<00:00, 6.16MB/s]
#  98%|█████████▊| 178M/181M [00:31<00:00, 6.50MB/s]
#  99%|█████████▉| 179M/181M [00:31<00:00, 6.63MB/s]
#  99%|█████████▉| 180M/181M [00:31<00:00, 6.51MB/s]
# 100%|█████████▉| 181M/181M [00:32<00:00, 6.50MB/s]
# 100%|██████████| 181M/181M [00:32<00:00, 5.91MB/s]
# "unzip" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
import os
#unzip
# !tar -xf face-recognition-dataset.zip -C ./data

# %%
#Delete zip
os.remove('face-recognition-dataset.zip')

# %%
# Delete extracted faces
import shutil
shutil.rmtree("data/Extracted Faces/")

# %% [markdown]
# Ordenamiento de datos
#
# Mover los archivos a la carpeta data

# %%
import shutil
import os

def move_files(source_folder, destination_folder):
    # Check if both source and destination folders exist
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return
    
    if not os.path.exists(destination_folder):
        print(f"Destination folder '{destination_folder}' does not exist.")
        return

    # Get the list of files in the source folder
    files = os.listdir(source_folder)
    
    # Move each file from the source folder to the destination folder
    for file in files:
        source_file_path = os.path.join(source_folder, file)
        destination_file_path = os.path.join(destination_folder, file)
        shutil.move(source_file_path, destination_file_path)
        print(f"Moved '{file}' to '{destination_folder}'.")

# Example usage
source_folder = "data/Face Data/Face Dataset"
destination_folder = "data"

move_files(source_folder, destination_folder)

# %%
shutil.rmtree("data/Face Data")

# %% [markdown]
# A continuación se organizan los datos descargados en dos carpetas, train y test.

# %%
import os
import shutil
import random

data_folder = "data"
train_folder = "train"
test_folder = "test"
split_ratio = 0.8  # 80% for training

# Create "train" and "test" folders if they don't exist
if not os.path.exists(train_folder):
    os.mkdir(train_folder)
if not os.path.exists(test_folder):
    os.mkdir(test_folder)

# Function to split files into train and test folders
def split_files(src_folder, train_dest, test_dest, split_ratio):
    files = os.listdir(src_folder)
    random.shuffle(files)
    split_index = int(len(files) * split_ratio)
    train_files = files[:split_index]
    test_files = files[split_index:]

    for file in train_files:
        src_path = os.path.join(src_folder, file)
        dest_path = os.path.join(train_dest, file)
        shutil.move(src_path, dest_path)

    for file in test_files:
        src_path = os.path.join(src_folder, file)
        dest_path = os.path.join(test_dest, file)
        shutil.move(src_path, dest_path)


# Obtaining the list of subfolders
sub_folders = []

for root, dirs, files in os.walk(dataset_path):
    for dir in dirs:
        folder_path = os.path.join(root, dir)
        sub_folders.append(folder_path)


# Loop through subfolders in the "data" folder
for sub_f in sub_folders:

    if os.path.exists(sub_f):
        train_subfolder = os.path.join(train_folder, sub_f.split('/')[-1])
        test_subfolder = os.path.join(test_folder, sub_f.split('/')[-1])
        os.mkdir(train_subfolder)
        os.mkdir(test_subfolder)
        split_files(sub_f, train_subfolder, test_subfolder, split_ratio)
